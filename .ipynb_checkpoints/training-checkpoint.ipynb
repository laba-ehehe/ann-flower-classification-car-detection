# %% [markdown]
# # Training Notebook

# %% [markdown]
# ### Import libraries and magic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Dataset 1: Flower Species Dataset

# %%
X_train_flower = np.load('flower_species_classification/data_train.npy').reshape(-1, 300, 300, 3) / 255.0
y_train_flower = np.load('flower_species_classification/labels_train.npy')
y_train_flower_one_hot = tf.keras.utils.to_categorical(y_train_flower, num_classes=10)

X_train_flower.shape, y_train_flower.shape
# Out:
# ((1658, 300, 300, 3), (1658,))

# %%
# Build Flower Model

flower_model = Sequential([
    Input(shape=(300, 300, 3)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

flower_model.compile(optimizer=Adam(learning_rate=0.001),
                     loss='categorical_crossentropy',
                     metrics=['accuracy'])

flower_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 270000)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │   138,240,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 138,374,410 (527.86 MB)
#  Trainable params: 138,374,410 (527.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Flower Model

# early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

flower_history = flower_model.fit(X_train_flower, y_train_flower_one_hot,
                                  validation_split=0.2, epochs=30, batch_size=32
                                  )
# Out:
# Epoch 1/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.0942 - loss: 112.2980 - val_accuracy: 0.0753 - val_loss: 2.3026
# Epoch 2/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.1147 - loss: 2.5264 - val_accuracy: 0.0753 - val_loss: 2.3019
# Epoch 3/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1074 - loss: 2.3108 - val_accuracy: 0.1205 - val_loss: 2.3012
# Epoch 4/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.1279 - loss: 2.5630 - val_accuracy: 0.1205 - val_loss: 2.3003
# Epoch 5/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.1291 - loss: 2.3005 - val_accuracy: 0.1205 - val_loss: 2.2996
# Epoch 6/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 840ms/step - accuracy: 0.1230 - loss: 2.2988 - val_accuracy: 0.1205 - val_loss: 2.2992
# Epoch 7/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 933ms/step - accuracy: 0.1203 - loss: 2.2996 - val_accuracy: 0.1205 - val_loss: 2.2988
# Epoch 8/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.1223 - loss: 2.2983 - val_accuracy: 0.1205 - val_loss: 2.2983
# Epoch 9/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 970ms/step - accuracy: 0.1236 - loss: 2.2975 - val_accuracy: 0.1205 - val_loss: 2.2980
# Epoch 10/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.1263 - loss: 2.2972 - val_accuracy: 0.1205 - val_loss: 2.2978
# Epoch 11/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.1231 - loss: 2.2971 - val_accuracy: 0.1205 - val_loss: 2.2977
# Epoch 12/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.1393 - loss: 2.2956 - val_accuracy: 0.1205 - val_loss: 2.2975
# Epoch 13/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.1162 - loss: 2.2969 - val_accuracy: 0.1205 - val_loss: 2.2975
# Epoch 14/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.1203 - loss: 2.2970 - val_accuracy: 0.1205 - val_loss: 2.2975
# Epoch 15/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.1067 - loss: 2.2996 - val_accuracy: 0.1205 - val_loss: 2.2971
# Epoch 16/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 119s 3s/step - accuracy: 0.1244 - loss: 2.2962 - val_accuracy: 0.1205 - val_loss: 2.2973
# Epoch 17/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 124s 3s/step - accuracy: 0.1212 - loss: 2.2973 - val_accuracy: 0.1205 - val_loss: 2.2970
# Epoch 18/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - accuracy: 0.1335 - loss: 2.2952 - val_accuracy: 0.1205 - val_loss: 2.2971
# Epoch 19/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.1329 - loss: 2.2957 - val_accuracy: 0.1205 - val_loss: 2.2970
# Epoch 20/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.1005 - loss: 2.3005 - val_accuracy: 0.1205 - val_loss: 2.2969
# Epoch 21/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 861ms/step - accuracy: 0.1085 - loss: 2.2982 - val_accuracy: 0.1205 - val_loss: 2.2969
# Epoch 22/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 948ms/step - accuracy: 0.1120 - loss: 2.2989 - val_accuracy: 0.1205 - val_loss: 2.2968
# Epoch 23/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.1167 - loss: 2.2994 - val_accuracy: 0.1205 - val_loss: 2.2971
# Epoch 24/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.1330 - loss: 2.2895 - val_accuracy: 0.1205 - val_loss: 2.2971
# Epoch 25/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 924ms/step - accuracy: 0.1381 - loss: 2.2935 - val_accuracy: 0.1205 - val_loss: 2.2973
# Epoch 26/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 988ms/step - accuracy: 0.1052 - loss: 2.3022 - val_accuracy: 0.1205 - val_loss: 2.2975
# Epoch 27/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.1211 - loss: 2.2939 - val_accuracy: 0.1205 - val_loss: 2.2972
# Epoch 28/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.1231 - loss: 2.2952 - val_accuracy: 0.1205 - val_loss: 2.2973
# Epoch 29/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.1140 - loss: 2.2979 - val_accuracy: 0.1205 - val_loss: 2.2974
# Epoch 30/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.1342 - loss: 2.2941 - val_accuracy: 0.1205 - val_loss: 2.2975

# %%
# Save Flower Model

flower_model.save('flower_classifier.keras')

# %%
# Plot Training Results

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(flower_history.history['loss'], label='Train Loss')
plt.plot(flower_history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Flower Classification - Loss')
plt.subplot(1, 2, 2)
plt.plot(flower_history.history['accuracy'], label='Train Accuracy')
plt.plot(flower_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Flower Classification - Accuracy')
plt.savefig("flower.png", format="png")
plt.show()

# %%
# Save and plot Loss
plt.figure(figsize=(6, 5))
plt.plot(flower_history.history['loss'], label='Train Loss')
plt.plot(flower_history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Flower Classification - Loss')
plt.savefig("flower_loss.png", format="png")  # Save loss plot
plt.show()

# Save and plot Accuracy
plt.figure(figsize=(6, 5))
plt.plot(flower_history.history['accuracy'], label='Train Accuracy')
plt.plot(flower_history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Flower Classification - Accuracy')
plt.savefig("flower_accuracy.png", format="png")  # Save accuracy plot
plt.show()

# %% [markdown]
# ## Dataset 2: Car Detection Dataset

# %%
X_train_car = np.array([plt.imread('car_detection_dataset/training_images/' + img)
                        for img in pd.read_csv('car_detection_dataset/train_bounding_boxes.csv')['image']])
y_train_car = pd.read_csv('car_detection_dataset/train_bounding_boxes.csv').iloc[:, 1:].values
X_train_car = X_train_car / 255.0 # Normalize images

X_train_car.shape, y_train_car.shape
# Out:
# ((559, 380, 676, 3), (559, 4))

# %%
# Build Car Detection Model

car_model = Sequential([
    Input(shape=(380, 676, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='linear')
])

# Compile Car Detection Model

car_model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='mse', metrics=['mae'])

car_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 378, 674, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 189, 337, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 187, 335, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 93, 167, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 993984)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │   127,230,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 127,249,988 (485.42 MB)
#  Trainable params: 127,249,988 (485.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train Car Detection Model

# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


car_history = car_model.fit(X_train_car, y_train_car,
                            validation_split=0.2, epochs=30, batch_size=16)
# Out:
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - loss: 39271.8086 - mae: 148.0741 - val_loss: 25541.8711 - val_mae: 110.7843
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - loss: 21839.7402 - mae: 106.1274 - val_loss: 25525.4531 - val_mae: 124.9282
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - loss: 22369.8047 - mae: 107.7141 - val_loss: 23839.3418 - val_mae: 104.8552
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 71s 3s/step - loss: 20651.7617 - mae: 100.9994 - val_loss: 23752.6992 - val_mae: 107.3192
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 18279.3945 - mae: 94.9930 - val_loss: 22094.0098 - val_mae: 102.1965
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - loss: 18930.2012 - mae: 95.6027 - val_loss: 20207.2090 - val_mae: 95.4612
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - loss: 13840.9434 - mae: 80.6293 - val_loss: 20314.7988 - val_mae: 94.2013
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - loss: 11077.6201 - mae: 66.2802 - val_loss: 19501.8320 - val_mae: 91.7050
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - loss: 11746.6953 - mae: 65.2207 - val_loss: 19515.2461 - val_mae: 93.2136
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 11388.9697 - mae: 64.4405 - val_loss: 19548.7148 - val_mae: 92.1852
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 11595.3525 - mae: 67.3194 - val_loss: 21349.2363 - val_mae: 101.4763
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 12658.7627 - mae: 71.0705 - val_loss: 19834.5977 - val_mae: 92.9728
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 12410.7871 - mae: 66.7692 - val_loss: 19673.7070 - val_mae: 101.1583
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 10686.2510 - mae: 65.6492 - val_loss: 18767.3730 - val_mae: 91.9307
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 10577.9346 - mae: 60.8579 - val_loss: 18528.8574 - val_mae: 88.7740
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 10439.1289 - mae: 57.4922 - val_loss: 18728.4590 - val_mae: 91.7250
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 10531.4404 - mae: 59.9954 - val_loss: 19290.2168 - val_mae: 94.5484
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - loss: 11056.8818 - mae: 67.2225 - val_loss: 18579.7793 - val_mae: 90.8312
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 9232.6436 - mae: 57.4815 - val_loss: 19459.6816 - val_mae: 100.9606
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - loss: 10386.6094 - mae: 64.9834 - val_loss: 18488.3008 - val_mae: 91.0676
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - loss: 10260.3213 - mae: 55.6435 - val_loss: 19247.1895 - val_mae: 91.4329
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - loss: 10848.8545 - mae: 59.3936 - val_loss: 18575.3613 - val_mae: 91.3308
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - loss: 11305.3232 - mae: 62.6820 - val_loss: 18165.6289 - val_mae: 89.9662
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 10865.0430 - mae: 57.6606 - val_loss: 18111.1680 - val_mae: 89.8845
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - loss: 11514.4463 - mae: 65.7315 - val_loss: 18989.2598 - val_mae: 93.6518
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 11149.5820 - mae: 62.6146 - val_loss: 18453.1719 - val_mae: 90.3668
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - loss: 10687.6221 - mae: 57.8338 - val_loss: 18531.0312 - val_mae: 88.3728
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 8663.3945 - mae: 51.0617 - val_loss: 18559.5977 - val_mae: 91.7832
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 8870.6699 - mae: 54.0799 - val_loss: 18945.8066 - val_mae: 86.3258
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - loss: 11279.9551 - mae: 62.3360 - val_loss: 18629.8945 - val_mae: 95.0005

# %%
# Save Car Detection Model

car_model.save('car_detector.keras')

# %%
# Plot Training Results

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(car_history.history['loss'], label='Train Loss')
plt.plot(car_history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Car Detection - Loss')
plt.subplot(1, 2, 2)
plt.plot(car_history.history['mae'], label='Train MAE')
plt.plot(car_history.history['val_mae'], label='Validation MAE')
plt.legend()
plt.title('Car Detection - MAE')
plt.savefig("car.png", format="png")
plt.show()

# %%
# Save and plot Loss
plt.figure(figsize=(6, 5))
plt.plot(car_history.history['loss'], label='Train Loss')
plt.plot(car_history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Car Detection - Loss')
plt.savefig("car_loss.png", format="png")  # Save loss plot
plt.show()

# Save and plot MAE
plt.figure(figsize=(6, 5))
plt.plot(car_history.history['mae'], label='Train MAE')
plt.plot(car_history.history['val_mae'], label='Validation MAE')
plt.legend()
plt.title('Car Detection - MAE')
plt.savefig("car_mae.png", format="png")  # Save MAE plot
plt.show()
